# %%
import pandas as pd

df1 = pd.read_csv('CSV_files/HCMST_2017_public_data.csv')
df2 = pd.read_csv('CSV_files/HCMST_ver_3.csv')
# Out:
# C:\Users\megam\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (48,103) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\megam\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (76,77,78,79,90,91,92,93,108,150) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head()
# Out:
#    Unnamed: 0  CaseID  CASEID_NEW      qflag  weight1  weight1_freqwt  \
# 0           0       2     2014039  Qualified      NaN             NaN
# 1           1       3     2019003  Qualified   0.9078         71115.0
# 2           2       5     2145527  Qualified   0.7205         56442.0
# 3           3       6     2648857  Qualified   1.2597         98682.0
# 4           4       7     2623465  Qualified   0.8686         68044.0
#
#    weight2  weight1a  weight1a_freqwt  weight_combo  ...  \
# 0   0.8945       NaN              NaN      0.277188  ...
# 1      NaN    0.9026          70707.0      1.020621  ...
# 2      NaN    0.7164          56121.0      0.810074  ...
# 3   1.3507    1.2524          98110.0      0.418556  ...
# 4      NaN    0.8636          67652.0      0.976522  ...
#
#    hcm2017q24_met_through_family  hcm2017q24_met_through_friend  \
# 0                             no                             no
# 1                             no                             no
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0  caseid_new  weight1  weight2  ppage ppagecat ppagect4  \
# 0           0       22526     4265   4265.0     52    45-54    45-59
# 1           1       23286    16485  16485.0     28    25-34    18-29
# 2           2       25495    52464      NaN     49    45-54    45-59
# 3           3       26315     4575   4575.0     31    25-34    30-44
# 4           4       27355    12147      NaN     35    35-44    30-44
#
#                                               ppeduc  \
# 0                                   bachelors degree
# 1                                     masters degree
# 2  high school graduate - high school diploma or ...
# 3                                   associate degree
# 4  high school graduate - high school diploma or ...
#
#                       ppeducat               ppethm  ... w3_mbtiming_year  \
# 0  bachelor's degree or higher             hispanic  ...              NaN
# 1  bachelor's degree or higher  white, non-hispanic  ...              NaN
# ...

# %%
df1.shape
# Out:
# (3510, 286)

# %%
df2.shape
# Out:
# (4002, 388)
